# %% [markdown]
# <a href="https://colab.research.google.com/github/LilyHdz94/Talento_Tech/blob/main/ProyectoFinalExcel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # Traemos la clase drive, dentro del módulo colab, del paquete google
drive.mount('/content/drive') # Establecemos la conexión através del método mount
# Out:
# Mounted at /content/drive

# %%
#importamos la libreria para la manipulación da datos llamada Pandas
import pandas as pd

# %%
Establecimientos_Intervenidos = '/content/drive/MyDrive/Establecimientos Sanitarios Final/OSB Establecimientos Intervenidos.xlsx'
Tipo_de_Establecimiento_Intervenido= '/content/drive/MyDrive/Establecimientos Sanitarios Final/OBS Tipo de Establecimiento.xlsx'
Medidas_Sanitarias='/content/drive/MyDrive/Establecimientos Sanitarios Final/OSB Medidas Sanitarias.xlsx'
Concepto_Sanitario= '/content/drive/MyDrive/Establecimientos Sanitarios Final/OSB Conceptos Sanitarios.xlsx'

# %%
DF = pd.read_excel(Establecimientos_Intervenidos)
DF1= pd.read_excel(Tipo_de_Establecimiento_Intervenido)
DF2= pd.read_excel(Medidas_Sanitarias)
DF3= pd.read_excel(Concepto_Sanitario)

# %%
DF.head()
# Out:
#        Localidad  No establecimientos   año
# 0        Usaquén                 4728  2012
# 1      Chapinero                 2759  2012
# 2       Santa Fe                 4016  2012
# 3  San Cristóbal                 4066  2012
# 4           Usme                 5596  2012

# %%
DF.describe()
# Out:
#        No establecimientos          año
# count           231.000000   231.000000
# mean          12699.212121  2017.000000
# std           27980.537713     3.169145
# min              86.000000  2012.000000
# 25%            4569.500000  2014.000000
# 50%            6482.000000  2017.000000
# 75%            9084.000000  2020.000000
# max          178236.000000  2022.000000

# %%
Establecimientos_Intervenidos_Año= DF.groupby(['año', 'Localidad']) ['No establecimientos'].sum()
print(Establecimientos_Intervenidos_Año)
# Out:
# año   Localidad
# 2012  Antonio Nariño    2862
#       Barrios Unidos    2701
#       Bosa              8175
#       Candelaria        1330
#       Chapinero         2759
#                         ...
# 2022  Sumapaz            154
#       Teusaquillo       4526
#       Tunjuelito        6912
#       Usaquén           8232
#       Usme              8676
# Name: No establecimientos, Length: 231, dtype: int64

# %%
Establecimientos_Intervenidos_Año= DF.groupby('Localidad') ['No establecimientos'].sum()
print (Establecimientos_Intervenidos_Año)
# Out:
# Localidad
# Antonio Nariño          48439
# Barrios Unidos          54873
# Bosa                   100652
# Candelaria              16695
# Chapinero               50636
# Ciudad Bolívar         101772
# Distrito              1466759
# Engativá                85280
# Fontibón                81123
# Kennedy                156045
# La Candelaria            2191
# Los Mártires            75768
# Mártires                 9591
# Puente Aranda           68560
# Rafael Uribe Uribe      89243
# San Cristóbal           67952
# Santa Fe                60275
# Suba                   130181
# Sumapaz                  2068
# Teusaquillo             40861
# Tunjuelito              65566
# Usaquén                 79158
# Usme                    79830
# Name: No establecimientos, dtype: int64

# %%
Establecimientos_AntonioNariño= DF[DF['Localidad']=='Antonio Nariño']
print (Establecimientos_AntonioNariño)
# Out:
#           Localidad  No establecimientos   año
# 14   Antonio Nariño                 2862  2012
# 35   Antonio Nariño                 3223  2013
# 56   Antonio Nariño                 3521  2014
# 77   Antonio Nariño                 3551  2015
# 98   Antonio Nariño                 3044  2016
# 119  Antonio Nariño                 4965  2017
# 140  Antonio Nariño                 6258  2018
# 161  Antonio Nariño                 6039  2019
# 182  Antonio Nariño                 4551  2020
# 203  Antonio Nariño                 4920  2021
# 224  Antonio Nariño                 5505  2022

# %%
DF1.head()
# Out:
#    Nº     Área Tipo de Establecimiento  Número de establecimientos
# 0   1  USAQUÉN             RESTAURANTE                        1115
# 1   1  USAQUÉN             PELUQUERÍAS                         650
# 2   1  USAQUÉN         COMIDAS RÁPIDAS                         413
# 3   1  USAQUÉN               DROGUERÍA                         243
# 4   1  USAQUÉN               CAFETERÍA                         230

# %%
Tipo_Establecimiento_Localidad= DF1.groupby(['Área','Tipo de Establecimiento']) ['Número de establecimientos'].sum()
print (Tipo_Establecimiento_Localidad)
# Out:
# Área            Tipo de Establecimiento
# ANTONIO NARIÑO  ALMACÉN                           489
#                 CAFETERÍA                         242
#                 CIGARRERÍAS                       101
#                 COMERCIO DE PRODUCTOS TEXTILES    229
#                 COMIDAS RÁPIDAS                   248
#                                                  ...
# USME            HOGAR DE BIENESTAR                286
#                 PANADERÍA                         341
#                 PELUQUERÍAS                       352
#                 RESTAURANTE                       489
#                 TIENDAS                           134
# Name: Número de establecimientos, Length: 200, dtype: int64
